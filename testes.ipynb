# %%
import os
from os.path import join
import pandas as pd
from datetime import datetime, timedelta

# intervalo de datas
data_inicio = datetime.today()
data_fim = data_inicio + timedelta(days=7)

# formato de datas
data_inicio = data_inicio.strftime('%Y-%m-%d')
data_fim = data_fim.strftime('%Y-%m-%d')

city = 'Boston'
key = 'JL54FV532T94VV8EBVHAHDWE2'

url = join('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/',
            f'{city}/{data_inicio}/{data_fim}?unitGroup=metric&include=days&key={key}&contentType=csv')

dados = pd.read_csv(url)    
dados.head()
# Out:
#                         name    datetime  tempmax  tempmin  temp  \
# 0  Boston, MA, United States  2025-06-30     27.8     16.7  23.2
# 1  Boston, MA, United States  2025-07-01     27.3     21.7  24.2
# 2  Boston, MA, United States  2025-07-02     26.7     23.4  24.9
# 3  Boston, MA, United States  2025-07-03     27.3     21.2  24.2
# 4  Boston, MA, United States  2025-07-04     26.4     20.1  23.3
#
#    feelslikemax  feelslikemin  feelslike   dew  humidity  ...  solarenergy  \
# 0          29.0          16.7       23.3  17.0      68.8  ...         45.8
# 1          29.4          21.7       24.3  21.0      82.5  ...         20.9
# 2          26.7          23.4       24.9  19.3      71.6  ...         22.4
# 3          27.6          21.2       24.2  16.6      63.3  ...         22.1
# 4          26.4          20.1       23.3  13.1      54.1  ...         30.9
#
#    uvindex  severerisk              sunrise               sunset  moonphase  \
# 0        8          10  2025-06-30T05:10:59  2025-06-30T20:24:59       0.17
# 1        7          60  2025-07-01T05:11:29  2025-07-01T20:24:51       0.20
# 2        7          10  2025-07-02T05:12:02  2025-07-02T20:24:40       0.25
# 3        8          30  2025-07-03T05:12:36  2025-07-03T20:24:27       0.27
# 4        8          10  2025-07-04T05:13:11  2025-07-04T20:24:11       0.30
#
#                conditions                                        description  \
# 0        Partially cloudy                  Becoming cloudy in the afternoon.
# 1  Rain, Partially cloudy  Partly cloudy throughout the day with storms p...
# 2        Partially cloudy                  Partly cloudy throughout the day.
# 3        Partially cloudy                  Partly cloudy throughout the day.
# 4                   Clear               Clear conditions throughout the day.
#
#                 icon                                   stations
# 0  partly-cloudy-day  KOWD,AV085,KLWM,KBED,0518W,KBOS,KGHG,KBVY
# 1               rain                                        NaN
# 2  partly-cloudy-day                                        NaN
# 3  partly-cloudy-day                                        NaN
# 4          clear-day                                        NaN
#
# [5 rows x 33 columns]
